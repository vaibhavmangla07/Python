# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)
# SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=1000, n_redundant=0, n_features=2, n_clusters_per_class=1, weights=[0.90], random_state=12)

# %%
import pandas as pd
df1 = pd.DataFrame(X, columns=['Feature_1', 'Feature_2'])
df2 = pd.DataFrame(y, columns=['Target'])
final_df = pd.concat([df1, df2], axis=1)
final_df.head()
# Out:
#    Feature_1  Feature_2  Target
# 0  -0.762898  -0.706808       0
# 1  -1.075436  -1.051162       0
# 2  -0.610115  -0.909802       0
# 3  -2.023284  -0.428945       1
# 4  -0.812921  -1.316206       0

# %%
final_df['Target'].value_counts()
# Out:
# Target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['Feature_1'], final_df['Feature_2'], c=final_df['Target'])

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (from imblearn) (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (2.4.0)
# Requirement already satisfied: scipy<2,>=1.11.4 in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Users/vmangla/Documents/Vaibhav/Programming/Python/Python_ML_DL/.venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(final_df[['Feature_1', 'Feature_2']], final_df['Target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
y==0
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1795    False
# 1796    False
# 1797    False
# 1798    False
# 1799    False
# Name: Target, Length: 1800, dtype: bool

# %%
y[y==0]
# Out:
# 0      0
# 1      0
# 2      0
# 4      0
# 5      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Target, Length: 900, dtype: int64

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(X, columns=['Feature_1', 'Feature_2'])
df2 = pd.DataFrame(y, columns=['Target'])
oversample_df = pd.concat([df1, df2], axis=1)

# %%
plt.scatter(oversample_df['Feature_1'], oversample_df['Feature_2'], c=oversample_df['Target'])
