# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('data/height-weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
# Scatter plot of height vs weight
plt.scatter(df['Weight'], df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Height vs Weight')
plt.show()

# %%
# Correlation
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
# Seaborn pairplot
import seaborn as sns
sns.pairplot(df)

# %%
# Independent and dependent variables
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
# Independent and dependent variables
X = df[['Weight']]  # Independent variable should be 2D or dataframe for sklearn
print(type(X))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
y = df['Height']  # Dependent variable can be 1D or series
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
X_series = df['Weight']  # Independent variable as 1D series
np.array(X_series).shape
# Out:
# (23,)

# %%
np.array(X).shape
# Out:
# (23, 1)

# %%
np.array(y).shape
# Out:
# (23,)

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((17, 1), (6, 1), (17,), (6,))

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.87662801],
#        [ 1.66773133],
#        [ 0.33497168],
#        [-1.48242785],
#        [ 1.36483141],
#        [-1.6641678 ],
#        [-0.75546804],
#        [-0.1496682 ],
#        [ 0.21381171],
#        [-1.36126788],
#        [-0.99778797],
#        [-0.02850823],
#        [ 1.06193149],
#        [ 0.57729161],
#        [ 0.75903157],
#        [ 0.88019153],
#        [ 0.45613165]])

# %%
X_test_scaled
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
# Apply Simple Linear Regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Cofficient or Slope", model.coef_)
print("Intercept", model.intercept_)
# Out:
# Cofficient or Slope [1.04792503]
# Intercept 80.5268451262254

# %%
# Training data plot
plt.scatter(X_train, y_train)
plt.plot(X_train, model.predict(X_train), color='red')

# %%
# Prediction on test data
y_pred = model.predict(X_test)
y_pred
# Out:
# array([162.26499721, 162.26499721, 127.68347133, 180.07972266,
#        148.64197186, 190.55897293])

# %%
# Performance metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 114.84069295228699
# Mean Absolute Error: 9.66512588679501
# Root Mean Squared Error: 10.716374991212605
# R-squared: 0.7360826717981276

# %% [markdown]
# **Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]**
#
# where:
#
# R2: The R2 of the model
# n: The number of observations
# k: The number of predictor variables

# %%
#display adjusted R-squared
print("Adjusted R-squared", 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# Adjusted R-squared 0.6701033397476595

# %%
# OLS Linear Regression
import statsmodels.api as sm
ols_model = sm.OLS(y_train, X_train).fit()
pred = ols_model.predict(X_test)
pred
# Out:
# 15    164.134205
# 9     164.134205
# 0      94.692811
# 8     199.907045
# 17    136.778504
# 12    220.949891
# dtype: float64

# %%
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.985
# Method:                 Least Squares   F-statistic:                              1133.
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):                    2.80e-16
# Time:                        12:00:28   Log-Likelihood:                         -73.806
# No. Observations:                  17   AIC:                                      149.6
# Df Residuals:                      16   BIC:                                      150.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Prediction for new data
model.predict([[72]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([155.97744705])
